# %%
import contextlib
import ipynb.fs
import os
import matplotlib.pyplot as plt
import math
import pandas as pd
import praat_formants_python as pfp
import wave

from .defs.formant_vowel_prediction import vowel_prediction
from .defs.vowel_feedback_function import vowel_feedback
from .defs.extract_formant import extract_formant

from pathlib import Path
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

def uniq(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]

# %%
data_folder = Path('../../InterFra/extracted')

vowels_2 = {'oe': '9', 'OE': '2', 'aN': 'ã', 'EN': 'ẽ', 'ON': 'õ'}
vowels = ['a', 'e', 'E', 'i', 'o', 'O', 'u', 'y', '9', '2', 'ã', 'ẽ', 'õ']

y_true_nat = []
y_pred_nat = []
y_true_nnat = []
y_pred_nnat = []

y_true_f = []
y_pred_f = []
y_true_m = []
y_pred_m = []

for file in os.listdir(data_folder):
    path = (data_folder / file).as_posix()
    
    with contextlib.closing(wave.open(path,'r')) as f:
        frames = f.getnframes()
        rate = f.getframerate()
        duration = frames / float(rate)
    
    try:
        f1, f2, f3, f4 = extract_formant(path, start_time=0, end_time=duration, f0min=math.ceil(3/duration))
    except ZeroDivisionError:
        continue
    
    native = file.startswith('C')
    file2 = file.split('.')[0].split('_')[1:]
    attempted = file2[0].translate({ord(c): None for c in '0123456789'})
    ok = False
    for k, v in vowels_2.items():
        attempted = attempted.replace(k, v)

    for vowel in vowels:
        if vowel in attempted:
            ok = True
            idx = attempted.index(vowel)
            if idx == 1:
                attempted = vowel
                break
            elif idx == 0 and len(attempted) < 3:
                attempted = vowel
                break
            else:
                ok = False

    said = attempted
    if len(file2) > 1:
        said = file2[1]
        for k, v in vowels_2.items():
            said = said.replace(k, v)
            
    ref_data = pd.read_csv('vowel_formants.txt', header=0, sep=' ')
    vowel, min_dist = vowel_prediction([f1, f2, f3, f4], ref_data, formants=4)
    said = said.replace('õ', 'O').replace('ã', 'a').replace('ẽ', 'E') # TODO
    attempted = attempted.replace('õ', 'O').replace('ã', 'a').replace('ẽ', 'E') # TODO
    vowel = vowel[1:2]
    
    female = 'CAT' in file or 'ELS' in file
    
    if native:
        y_true_nat.append(said)
        y_pred_nat.append(vowel)
    else:
        y_true_nnat.append(said)
        y_pred_nnat.append(vowel)
        
    if female:
        y_true_f.append(said)
        y_pred_f.append(vowel)
    else:
        y_true_m.append(said)
        y_pred_m.append(vowel)
    
    out = f'[{said}/{attempted}] ' + ' '.join(vowel_feedback(attempted, said)).strip()
    print(out)

full_true = y_true_m + y_true_f
full_pred = y_pred_m + y_pred_f

print(classification_report(y_true_nat, y_pred_nat, digits=3, zero_division=0))
print(classification_report(y_true_nnat, y_pred_nnat, digits=3, zero_division=0))

print(classification_report(y_true_f, y_pred_f, digits=3, zero_division=0))
print(classification_report(y_true_m, y_pred_m, digits=3, zero_division=0))

print(classification_report(full_true, full_pred, digits=3, zero_division=0))

labels = uniq(full_true)

cm = confusion_matrix(full_true, full_pred, labels=labels)
disp = ConfusionMatrixDisplay(cm, display_labels=labels)
disp.plot()
plt.show()
# Out:
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/i] Close your mouth more!
# [o/O] Open your mouth more!
# [9/9] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [o/O] Open your mouth more!
# [o/O] Open your mouth more!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/u] Close your mouth more! Move your tongue further back!
# [y/y] Excellent! You sound like a native!
# [e/y] Round your lips! Close your mouth more!
# [e/i] Close your mouth more!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [e/i] Close your mouth more!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/i] Close your mouth more!
# [O/O] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/O] Round your lips! Close your mouth more! Move your tongue further back!
# [a/a] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/9] Round your lips!
# [E/9] Round your lips!
# [9/9] Excellent! You sound like a native!
# [E/9] Round your lips!
# [u/u] Excellent! You sound like a native!
#               precision    recall  f1-score   support
#
#            2      0.000     0.000     0.000         2
#            9      0.143     0.500     0.222         2
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.105     0.200     0.138        10
#            O      0.000     0.000     0.000         3
#            a      1.000     0.056     0.105        36
#            e      0.400     0.143     0.211        14
#            i      0.500     0.400     0.444        10
#            o      0.000     0.000     0.000         3
#            u      0.250     0.500     0.333         2
#            y      0.250     1.000     0.400         1
#
#     accuracy                          0.157        83
#    macro avg      0.221     0.233     0.154        83
# weighted avg      0.587     0.157     0.170        83
#
#               precision    recall  f1-score   support
#
#            2      0.118     0.400     0.182         5
#            9      0.111     0.083     0.095        12
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.105     0.133     0.118        15
#            O      1.000     0.167     0.286         6
#            a      0.000     0.000     0.000        19
#            e      0.000     0.000     0.000        10
#            i      0.800     0.364     0.500        11
#            o      0.000     0.000     0.000         3
#            u      0.000     0.000     0.000         4
#            y      0.000     0.000     0.000         3
#
#     accuracy                          0.114        88
#    macro avg      0.178     0.096     0.098        88
# weighted avg      0.208     0.114     0.125        88
#
#               precision    recall  f1-score   support
#
#            2      0.333     0.286     0.308         7
#            9      0.000     0.000     0.000         5
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.138     0.364     0.200        11
#            O      0.000     0.000     0.000         5
#            a      1.000     0.062     0.118        32
#            e      0.250     0.071     0.111        14
#            i      0.615     0.444     0.516        18
#            o      0.000     0.000     0.000         5
#            u      0.000     0.000     0.000         3
#            y      0.000     0.000     0.000         1
#
#     accuracy                          0.168       101
#    macro avg      0.195     0.102     0.104       101
# weighted avg      0.499     0.168     0.188       101
#
#               precision    recall  f1-score   support
#
#            2      0.000     0.000     0.000         0
#            9      0.154     0.222     0.182         9
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.000     0.000     0.000        14
#            O      0.333     0.250     0.286         4
#            a      0.000     0.000     0.000        23
#            e      0.333     0.100     0.154        10
#            i      0.000     0.000     0.000         3
#            o      0.000     0.000     0.000         1
#            u      0.333     0.333     0.333         3
#            y      0.333     0.333     0.333         3
#
#     accuracy                          0.086        70
#    macro avg      0.124     0.103     0.107        70
# weighted avg      0.115     0.086     0.090        70
#
#               precision    recall  f1-score   support
#
#            2      0.087     0.286     0.133         7
#            9      0.125     0.143     0.133        14
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.105     0.160     0.127        25
#            O      0.200     0.111     0.143         9
#            a      1.000     0.036     0.070        55
#            e      0.286     0.083     0.129        24
#            i      0.615     0.381     0.471        21
#            o      0.000     0.000     0.000         6
#            u      0.250     0.167     0.200         6
#            y      0.200     0.250     0.222         4
#
#     accuracy                          0.135       171
#    macro avg      0.239     0.135     0.136       171
# weighted avg      0.490     0.135     0.153       171

# %%
data_folder = Path('../../Classmate corpus/extracted')

vowels_2 = {'oe': '9', 'OE': '2'}
vowels = ['a', 'e', 'E', 'i', 'o', 'O', 'u', 'y', '9', '2']

y_true_nat = []
y_pred_nat = []
y_true_nnat = []
y_pred_nnat = []

y_true_f = []
y_pred_f = []
y_true_m = []
y_pred_m = []

for file in os.listdir(data_folder):
    path = (data_folder / file).as_posix()
    
    with contextlib.closing(wave.open(path,'r')) as f:
        frames = f.getnframes()
        rate = f.getframerate()
        duration = frames / float(rate)
    
    try:
        f1, f2, f3, f4 = extract_formant(path, start_time=0, end_time=duration, f0min=math.ceil(3/duration))
    except ZeroDivisionError:
        continue
    
    native = any(file.startswith(x) for x in ['Jimmy', 'Kevin', 'Mathilde', 'Maxime', 'Omar'])
    file2 = file.split('.')[0].split('_')[1:]
    attempted = file2[0].translate({ord(c): None for c in '0123456789'})
    ok = False
    for k, v in vowels_2.items():
        attempted = attempted.replace(k, v)

    for vowel in vowels:
        if vowel in attempted:
            ok = True
            idx = attempted.index(vowel)
            if idx == 1:
                attempted = vowel
                break
            elif idx == 0 and len(attempted) < 3:
                attempted = vowel
                break
            else:
                ok = False
    

    said = attempted
    if len(file2) > 1:
        said = file2[1].translate({ord(c): None for c in '0123456789'})
        for k, v in vowels_2.items():
            said = said.replace(k, v)
            
    ref_data = pd.read_csv('vowel_formants.txt', header=0, sep=' ')
    vowel, min_dist = vowel_prediction([f1, f2, f3, f4], ref_data, formants=4)
    said = said.replace('õ', 'O').replace('ã', 'a').replace('ẽ', 'E') # TODO
    
    vowel = vowel[1:2]
    
    female = any(file.startswith(x) for x in ['Dimitra', 'Mathilde'])
    
    if native:
        y_true_nat.append(said)
        y_pred_nat.append(vowel)
    else:
        y_true_nnat.append(said)
        y_pred_nnat.append(vowel)
        
    if female:
        y_true_f.append(said)
        y_pred_f.append(vowel)
    else:
        y_true_m.append(said)
        y_pred_m.append(vowel)
    
    out = f'[{said}/{attempted}] ' + ' '.join(vowel_feedback(attempted, said)).strip()
    print(out)

full_true = y_true_m + y_true_f
full_pred = y_pred_m + y_pred_f
    
print(classification_report(y_true_nat, y_pred_nat, digits=3, zero_division=0))
print(classification_report(y_true_nnat, y_pred_nnat, digits=3, zero_division=0))

print(classification_report(y_true_f, y_pred_f, digits=3, zero_division=0))
print(classification_report(y_true_m, y_pred_m, digits=3, zero_division=0))

print(classification_report(y_true_m + y_true_f, y_pred_m + y_pred_f, digits=3, zero_division=0))

labels = uniq(full_true)

cm = confusion_matrix(full_true, full_pred, labels=labels)
disp = ConfusionMatrixDisplay(cm, display_labels=labels)
disp.plot()
plt.show()
# Out:
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [e/2] Round your lips!
# [O/o] Close your mouth more!
# [O/O] Excellent! You sound like a native!
# [9/u] Close your mouth more! Move your tongue further back!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [E/e] Close your mouth more! Move your tongue forward!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [E/2] Round your lips! Close your mouth more! Move your tongue forward!
# [E/2] Round your lips! Close your mouth more! Move your tongue forward!
# [O/o] Close your mouth more!
# [9/u] Close your mouth more! Move your tongue further back!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [a/O] Round your lips! Close your mouth more! Move your tongue further back!
# [u/u] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [a/a] Excellent! You sound like a native!
# [e/e] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [E/E] Excellent! You sound like a native!
# [i/i] Excellent! You sound like a native!
# [o/o] Excellent! You sound like a native!
# [O/O] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [2/2] Excellent! You sound like a native!
# [9/9] Excellent! You sound like a native!
# [u/u] Excellent! You sound like a native!
# [y/y] Excellent! You sound like a native!
#               precision    recall  f1-score   support
#
#            2      0.000     0.000     0.000         5
#            9      0.444     0.400     0.421        10
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.500     0.375     0.429         8
#            O      0.375     0.600     0.462         5
#            a      1.000     0.111     0.200         9
#            e      0.500     0.571     0.533         7
#            i      0.800     0.800     0.800         5
#            o      0.500     0.200     0.286         5
#            u      0.000     0.000     0.000         5
#            y      0.333     0.400     0.364         5
#
#     accuracy                          0.344        64
#    macro avg      0.371     0.288     0.291        64
# weighted avg      0.484     0.344     0.355        64
#
#               precision    recall  f1-score   support
#
#            2      0.000     0.000     0.000         2
#            9      0.375     0.500     0.429         6
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.200     0.143     0.167         7
#            O      0.400     0.500     0.444         4
#            a      1.000     0.286     0.444         7
#            e      0.286     0.400     0.333         5
#            i      0.500     0.667     0.571         3
#            o      0.000     0.000     0.000         1
#            u      0.000     0.000     0.000         1
#            y      0.333     0.333     0.333         3
#
#     accuracy                          0.333        39
#    macro avg      0.258     0.236     0.227        39
# weighted avg      0.415     0.333     0.334        39
#
#               precision    recall  f1-score   support
#
#            2      0.000     0.000     0.000         1
#            9      0.000     0.000     0.000         4
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.000     0.000     0.000         6
#            O      0.000     0.000     0.000         3
#            a      1.000     0.250     0.400         4
#            e      0.000     0.000     0.000         2
#            i      0.000     0.000     0.000         2
#            o      0.000     0.000     0.000         1
#            u      0.000     0.000     0.000         1
#            y      0.000     0.000     0.000         2
#
#     accuracy                          0.038        26
#    macro avg      0.083     0.021     0.033        26
# weighted avg      0.154     0.038     0.062        26
#
#               precision    recall  f1-score   support
#
#            2      0.000     0.000     0.000         6
#            9      0.438     0.583     0.500        12
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.667     0.444     0.533         9
#            O      0.385     0.833     0.526         6
#            a      1.000     0.167     0.286        12
#            e      0.667     0.600     0.632        10
#            i      0.750     1.000     0.857         6
#            o      0.500     0.200     0.286         5
#            u      0.000     0.000     0.000         5
#            y      0.500     0.500     0.500         6
#
#     accuracy                          0.442        77
#    macro avg      0.409     0.361     0.343        77
# weighted avg      0.548     0.442     0.432        77
#
#               precision    recall  f1-score   support
#
#            2      0.000     0.000     0.000         7
#            9      0.412     0.438     0.424        16
#            @      0.000     0.000     0.000         0
#            A      0.000     0.000     0.000         0
#            E      0.364     0.267     0.308        15
#            O      0.385     0.556     0.455         9
#            a      1.000     0.188     0.316        16
#            e      0.400     0.500     0.444        12
#            i      0.667     0.750     0.706         8
#            o      0.500     0.167     0.250         6
#            u      0.000     0.000     0.000         6
#            y      0.333     0.375     0.353         8
#
#     accuracy                          0.340       103
#    macro avg      0.338     0.270     0.271       103
# weighted avg      0.459     0.340     0.348       103
